# %% [markdown]
# **Constructors** are generally used for **instantiating an object**.
#
# The task of constructors is to initialize(assign values) to the data members of the class when an object of class is created.
#
# In Python the __init__() method is called the constructor and is always called when an object is created.

# %% [markdown]
# **Syntax:**
#
# ```
# def __init__(self):
#     # body of the constructor
# ```

# %%
class Person:
    def __init__(self):
        print(f'Initializing a new Person object: {self}')

# %%
p = Person()
# Out:
# Initializing a new Person object: <__main__.Person object at 0x0533EF90>

# %% [markdown]
# Python automatically calls ```__init__``` method when we creates an onject as a bound method.
#
# **Note :** ```__init__``` method is called after the object is already instantiated.

# %%
class Person:
    def __init__(self):
        # Just to verify the above statement
        print(self.__dict__)   # its been already instantiated.
        print(f'Initializing a new Person object: {self}')

# %%
# we can see its been already instantiated --
p = Person()
# Out:
# {}
# Initializing a new Person object: <__main__.Person object at 0x0533E1B0>

# %% [markdown]
# <h3>Types of constructors :</h3>
#
#    **Default constructor** :The default constructor is simple constructor which doesn’t accept any arguments.It’s definition has only one argument which is a reference to the instance being constructed.
#    <br>**Parameterized constructor** :constructor with parameters is known as parameterized constructor.The parameterized constructor take its first argument as a reference to the instance being constructed known as self and the rest of the arguments are provided by the programmer.

# %% [markdown]
# Above ```class Person:```'s constructor was a default constructor

# %% [markdown]
# Parameterized ```__init__``` method :

# %%
class Person:
    def __init__(self, name):
        self.name = name
        print(f'Initializing a new Person object: {self}')

# %%
p = Person('Sarthak')
# Out:
# Initializing a new Person object: <__main__.Person object at 0x066F5050>

# %%
p.__dict__
# Out:
# {'name': 'Sarthak'}

# %%
p.__init__
# Out:
# <bound method Person.__init__ of <__main__.Person object at 0x066F5050>>

# %%
# We can call it again whenever we want --
p.__init__('Sarthakk')
p.__dict__
# Out:
# Initializing a new Person object: <__main__.Person object at 0x066F5050>
# {'name': 'Sarthakk'}
